# %%
#!/usr/bin/env python
import ROOT as ROOT
from ROOT import TCanvas, TColor, TGaxis, TH1F, TPad, TFile, TGraphAsymmErrors,TLatex,TLine,gStyle,TLegend,TH2D
import os, datetime
import random
import sys, optparse
import array
import math
import getpass
import socket
import json
datestr = datetime.datetime.now().strftime("%I%p%Y%m%d")
# Out:
# Welcome to JupyROOT 6.16/00

# %%
inputFilename = 'Btageff_Output.root'
inputFile = TFile(inputFilename, 'READ')
outputFilename = 'btag_eff_forweight.root'
outputFile = TFile(outputFilename, 'RECREATE')
  
for partonFlavor in ['b','light']:
    denominatorIn = inputFile.Get('h_'+partonFlavor+'eff_den')
    numeratorIn = inputFile.Get('h_'+partonFlavor+'eff_num')
    
    xShift = denominatorIn.GetXaxis().GetBinWidth(1)/2.
    yShift = denominatorIn.GetYaxis().GetBinWidth(1)/2.
    
    denominatorOut = TH2D('denominator_' + partonFlavor, '', 10,-2.4,2.4,20,20.,1000.)
    numeratorOut   = TH2D('numerator_' + partonFlavor, '', 10,-2.4,2.4,20,20.,1000.)
    efficiencyOut  = TH2D('efficiency_' + partonFlavor, '', 10,-2.4,2.4,20,20.,1000.)

    for i in range(1,denominatorOut.GetXaxis().GetNbins()+1):
      for j in range(1,denominatorOut.GetYaxis().GetNbins()+1):
        binXMin = denominatorIn.GetXaxis().FindBin(denominatorOut.GetXaxis().GetBinLowEdge(i)+xShift)
        binXMax = denominatorIn.GetXaxis().FindBin(denominatorOut.GetXaxis().GetBinUpEdge(i)-xShift)
        binYMinPos = denominatorIn.GetYaxis().FindBin(denominatorOut.GetYaxis().GetBinLowEdge(j)+yShift)
        binYMaxPos = denominatorIn.GetYaxis().FindBin(denominatorOut.GetYaxis().GetBinUpEdge(j)-yShift)
        binYMinNeg = denominatorIn.GetYaxis().FindBin(-denominatorOut.GetYaxis().GetBinUpEdge(j)+yShift)
        binYMaxNeg = denominatorIn.GetYaxis().FindBin(-denominatorOut.GetYaxis().GetBinLowEdge(j)-yShift)

        denominator = denominatorIn.Integral(binXMin,binXMax,binYMinPos,binYMaxPos)
        denominator = denominator + denominatorIn.Integral(binXMin,binXMax,binYMinNeg,binYMaxNeg)
        numerator = numeratorIn.Integral(binXMin,binXMax,binYMinPos,binYMaxPos)
        numerator = numerator + numeratorIn.Integral(binXMin,binXMax,binYMinNeg,binYMaxNeg)

        if(i==denominatorOut.GetXaxis().GetNbins()): # also add overflow to the last bin in jet pT
          denominator = denominator + denominatorIn.Integral(binXMax+1,denominatorIn.GetXaxis().GetNbins()+1,binYMinPos,binYMaxPos)
          denominator = denominator + denominatorIn.Integral(binXMax+1,denominatorIn.GetXaxis().GetNbins()+1,binYMinNeg,binYMaxNeg)
          numerator = numerator + numeratorIn.Integral(binXMax+1,numeratorIn.GetXaxis().GetNbins()+1,binYMinPos,binYMaxPos)
          numerator = numerator + numeratorIn.Integral(binXMax+1,numeratorIn.GetXaxis().GetNbins()+1,binYMinNeg,binYMaxNeg)

        denominatorOut.SetBinContent(i,j,denominator)
        numeratorOut.SetBinContent(i,j,numerator)
        if(denominator>0.): efficiencyOut.SetBinContent(i,j,numerator/denominator)

    # check if there are any bins with 0 or 100% efficiency
    for i in range(1,denominatorOut.GetXaxis().GetNbins()+1):
      for j in range(1,denominatorOut.GetYaxis().GetNbins()+1):

        efficiency = efficiencyOut.GetBinContent(i,j)
        if(efficiency==0. or efficiency==1.):
          print ('Warning! Bin(%i,%i) for %s jets has a b-tagging efficiency of %.3f'%(i,j,partonFlavor,efficiency))

    # set efficiencies in overflow bins
    for i in range(1,denominatorOut.GetXaxis().GetNbins()+1):
      efficiencyOut.SetBinContent(i, denominatorOut.GetYaxis().GetNbins()+1, efficiencyOut.GetBinContent(i, denominatorOut.GetYaxis().GetNbins()))

    for j in range(1,denominatorOut.GetYaxis().GetNbins()+2):
      efficiencyOut.SetBinContent(denominatorOut.GetXaxis().GetNbins()+1, j, efficiencyOut.GetBinContent(denominatorOut.GetXaxis().GetNbins(), j))

    outputFile.cd()
    denominatorOut.Write()
    numeratorOut.Write()
    efficiencyOut.Write()
outputFile.Close()

print ('-------------------------------------------------------------------------------------------')
print ('successfully created and stored in %s'%outputFilename)
print ('')
# Out:
# Warning! Bin(1,9) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(1,10) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(1,11) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(1,12) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(1,13) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(1,14) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(1,15) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(1,16) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(1,17) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(1,18) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(1,19) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(1,20) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(2,9) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(2,10) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(2,11) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(2,12) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(2,13) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(2,14) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(2,15) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(2,16) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(2,17) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(2,18) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(2,19) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(2,20) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(3,9) for b jets has a b-tagging efficiency of 1.000
# Warning! Bin(3,10) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(3,11) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(3,12) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(3,13) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(3,14) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(3,15) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(3,16) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(3,17) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(3,18) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(3,19) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(3,20) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(4,9) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(4,10) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(4,11) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(4,12) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(4,13) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(4,14) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(4,15) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(4,16) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(4,17) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(4,18) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(4,19) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(4,20) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(5,9) for b jets has a b-tagging efficiency of 1.000
# Warning! Bin(5,10) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(5,11) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(5,12) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(5,13) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(5,14) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(5,15) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(5,16) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(5,17) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(5,18) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(5,19) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(5,20) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(6,9) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(6,10) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(6,11) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(6,12) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(6,13) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(6,14) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(6,15) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(6,16) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(6,17) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(6,18) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(6,19) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(6,20) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(7,9) for b jets has a b-tagging efficiency of 1.000
# Warning! Bin(7,10) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(7,11) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(7,12) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(7,13) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(7,14) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(7,15) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(7,16) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(7,17) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(7,18) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(7,19) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(7,20) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(8,9) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(8,10) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(8,11) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(8,12) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(8,13) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(8,14) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(8,15) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(8,16) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(8,17) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(8,18) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(8,19) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(8,20) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(9,9) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(9,10) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(9,11) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(9,12) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(9,13) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(9,14) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(9,15) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(9,16) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(9,17) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(9,18) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(9,19) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(9,20) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(10,8) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(10,9) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(10,10) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(10,11) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(10,12) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(10,13) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(10,14) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(10,15) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(10,16) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(10,17) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(10,18) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(10,19) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(10,20) for b jets has a b-tagging efficiency of 0.000
# Warning! Bin(1,9) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(1,10) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(1,11) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(1,12) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(1,13) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(1,14) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(1,15) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(1,16) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(1,17) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(1,18) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(1,19) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(1,20) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(2,9) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(2,10) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(2,11) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(2,12) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(2,13) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(2,14) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(2,15) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(2,16) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(2,17) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(2,18) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(2,19) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(2,20) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(3,9) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(3,10) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(3,11) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(3,12) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(3,13) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(3,14) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(3,15) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(3,16) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(3,17) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(3,18) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(3,19) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(3,20) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(4,9) for light jets has a b-tagging efficiency of 1.000
# Warning! Bin(4,10) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(4,11) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(4,12) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(4,13) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(4,14) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(4,15) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(4,16) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(4,17) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(4,18) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(4,19) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(4,20) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(5,9) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(5,10) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(5,11) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(5,12) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(5,13) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(5,14) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(5,15) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(5,16) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(5,17) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(5,18) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(5,19) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(5,20) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(6,9) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(6,10) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(6,11) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(6,12) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(6,13) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(6,14) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(6,15) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(6,16) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(6,17) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(6,18) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(6,19) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(6,20) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(7,9) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(7,10) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(7,11) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(7,12) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(7,13) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(7,14) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(7,15) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(7,16) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(7,17) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(7,18) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(7,19) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(7,20) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(8,9) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(8,10) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(8,11) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(8,12) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(8,13) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(8,14) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(8,15) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(8,16) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(8,17) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(8,18) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(8,19) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(8,20) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(9,9) for light jets has a b-tagging efficiency of 1.000
# Warning! Bin(9,10) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(9,11) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(9,12) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(9,13) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(9,14) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(9,15) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(9,16) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(9,17) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(9,18) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(9,19) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(9,20) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(10,8) for light jets has a b-tagging efficiency of 1.000
# Warning! Bin(10,9) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(10,10) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(10,11) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(10,12) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(10,13) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(10,14) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(10,15) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(10,16) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(10,17) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(10,18) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(10,19) for light jets has a b-tagging efficiency of 0.000
# Warning! Bin(10,20) for light jets has a b-tagging efficiency of 0.000
# -------------------------------------------------------------------------------------------
# successfully created and stored in btag_eff_forweight.root
